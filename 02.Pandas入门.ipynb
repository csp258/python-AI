# %%
import pandas as pd

#构造dataframe --创建数据集(学员成绩信息)
df = pd.DataFrame([{"姓名":"小王","语文":80,"数学":90,"英语":85},
                {"姓名":"小李","语文":75,"数学":95,"英语":80},
                {"姓名":"小张","语文":85,"数学":88,"英语":90},
                {"姓名":"小赵","语文":90,"数学":92,"英语":88},
                {"姓名":"小刘","语文":78,"数学":85,"英语":82},
                {"姓名":"小陈","语文":82,"数学":87,"英语":84},
                {"姓名":"小孙","语文":88,"数学":90,"英语":86},
                {"姓名":"小周","语文":80,"数学":85,"英语":80},
                {"姓名":"小吴","语文":85,"数学":92,"英语":88},
                {"姓名":"小郑","语文":90,"数学":95,"英语":92},
                {"姓名":"小冯","语文":78,"数学":80,"英语":82},
                {"姓名":"小韩","语文":82,"数学":88,"英语":84},
                {"姓名":"小杨","语文":88,"数学":90,"英语":86},
                {"姓名":"小明","语文":80,"数学":85,"英语":80},
                {"姓名":"小钱","语文":85,"数学":92,"英语":88},
                {"姓名":"小孙","语文":90,"数学":95,"英语":92},
                {"姓名":"小红","语文":78,"数学":80,"英语":82},
                {"姓名":"小王","语文":82,"数学":88,"英语":84},
                {"姓名":"小张","语文":88,"数学":90,"英语":86}
                    
                  ])
print(f"语文最高分: {df['语文'].max()}, 语文最低分: {df['语文'].min()}, 语文平均分: {df['语文'].mean():.2f}")
print(f"数学最高分: {df['数学'].max()}, 数学最低分: {df['数学'].min()}, 数学平均分: {df['数学'].mean():.2f}")
print(f"英语最高分: {df['英语'].max()}, 英语最低分: {df['英语'].min()}, 英语平均分: {df['英语'].mean():.2f}")


#统计计算
# Out:
# 语文最高分: 90, 语文最低分: 75, 语文平均分: 83.37
# 数学最高分: 95, 数学最低分: 80, 数学平均分: 88.79
# 英语最高分: 92, 英语最低分: 80, 英语平均分: 85.21
