# %%
import pandas as pd


# #读取数据
# df = pd.read_csv('素材/sales.csv',usecols=['订单号','产品类别','产品名称','销售数量','单价'])

# #数据处理
# df['销售金额'] = df['销售数量'] * df['单价']

# #数据写入 --> 保存到csv文件,---index=False 不保存索引
# df.to_csv('素材/sales_01.csv',index=False)



# #数据查看 -->head,tail,describe,info,shape,columns

# df1 = pd.read_csv('素材/sales.csv',usecols=['订单号','产品类别','产品名称','销售数量','单价'])
# # df1.head() #查看前五行
# # df1.tail() #查看后五行
# # df1.describe() #查看统计信息
# # df1.info() #查看数据信息(索引,列名,数据类型,非空值的个数,内存占用)
# # df1.shape #查看数据的维度(行,列)
# # df1.columns #查看列名


# #数据选择
# df2= pd.read_csv('素材/sales.csv',usecols=['订单号','产品类别','产品名称','销售数量','单价'])
# df2

# #1.选择列

# #1.1单列
# # df2['产品类别']

# #1.2多列
# # df2[['产品类别','产品名称']]

# #2.选择行
# #2.1 iloc  -->基于行号选择行(不包含结束位置),语法:df.iloc[开始行号:结束行号:步长]
# # df2.iloc[0:5]

# # #2.2 loc  -->基于行索引选择行(包含结束位置),语法:df.loc[开始索引:结束索引:步长]
# # df2.loc[0:5]

df3 = pd.read_csv('素材/sales.csv')
#配置项 展示所有的数据
# pd.set_option('display.max_rows', None)

#数据过滤
#1. 获取所有销售数量大于等于10的订单数据  
df3[df3['销售数量']>=10]

#2. 获取产品类型为 食品 或图书 的订单数据
df3[df3['产品类别'].isin(['食品','图书'])]

#3.获取 单价在100-200之间的订单数据 -->范围:between -->默认包含边界值
df3[df3['单价'].between(100,200)]

#4.获取销售数量>=8, 并且单价>=100的订单数据 ----> 逻辑与: & 逻辑或: | 多条件要用括号
df3[(df3['销售数量']>=8) & (df3['单价']>=100)]

#5.获取产品类型为 服装 或食品 的订单数据,支付方式为 支付宝或微信支付
df3[(df3['产品类别'].isin(['服装','食品'])) & (df3['支付方式'].isin(['支付宝','微信支付']))]
# Out:
#             订单号 产品类别 产品名称  销售数量   单价 客户所在城市  支付方式        订单日期
# 4    6801664364   食品   薯片     2   19    NaN  微信支付  2025/06/02
# 10   5808071569   食品  矿泉水     9   29     重庆   支付宝  2025-06-04
# 16   5812573980   食品   坚果     2   79     南京  微信支付  2025-06-05
# 23   6867258691   服装   围巾     8  129     青岛  微信支付  2025-06-07
# 25   6837065480   服装   毛衣     3  399     深圳  微信支付  2025-06-07
# ..          ...  ...  ...   ...  ...    ...   ...         ...
# 993  6870828210   服装   内衣     8   89     广州  微信支付  2026-03-20
# 994  5860722276   服装   外套     6  599     广州  微信支付  2026-03-20
# 996  5808511756   食品   坚果     2   79     成都   支付宝  2026-03-20
# 997  5811169466   服装   围巾     4  129     南京   支付宝  2026-03-20
# 998  6876456690   食品   果汁     7   39     广州   支付宝  2026-03-20
#
# [297 rows x 8 columns]
