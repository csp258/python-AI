# %%
# import matplotlib.pyplot as plt

# #绘制一个简单的折线图
# x = [1,3,41,2,5,6,7, 24,5,7,6,1,74,16,45,56]
# y = [1,9,3,6,5,6,17, 2,8,7,52,1,45,16,45,56]

# plt.plot(x,y)#绘制折线图
# plt.show()#显示图表

# %%
import matplotlib.pyplot as plt
import random

#展示中文
plt.rcParams['font.sans-serif'] = ['SimHei'] #设置中文字体为黑体


x= [i for i in range(1,25)]
y_bj= [random.randint(10,15) for i in x]
y_xa= [random.randint(13,18) for i in x]


plt.figure(figsize=(10,5))  #设置图表布大小为10*5
plt.plot(x,y_bj,label='北京') #绘制折线图 如果没有画布 会自动创建一个画布
plt.plot(x,y_xa,label='西安')

#设置折线图的详细信息
plt.title('气温变化折线图',fontsize=15) #设置标题字体大小为15
plt.xlabel('时间',fontsize=12) #设置x轴标签 字体大小为12
plt.ylabel('温度',fontsize=12) #设置y轴标签 字体大小为12
plt.xticks(x) #设置x轴刻度为1-24
plt.yticks(range(5,21)) #设置y轴刻度为5-20
plt.grid(linestyle='--') #显示网格线
plt.legend() #添加图例



plt.show()
