# %%
import pandas as pd

#创建dataframe
df1 = pd.DataFrame([
    {"姓名": "张三", "语文": 90, "英语": 88, "数学": 85},
    {"姓名": "李四", "语文": 85, "英语": 90, "数学": 88},
    {"姓名": "王五", "语文": 88, "英语": 85, "数学": 90},
])


df2 = pd.DataFrame({
    "姓名": ["张三", "李四", "王五"],
    "语文": [90, 85, 88],
    "英语": [88, 90, 85],
    "数学": [85, 88, 90],
})


df3 = pd.DataFrame([
    ["张三", 90, 88, 85],
    ["李四", 85, 90, 88],
    ["王五", 88, 85, 90],
], columns=["name", "语文", "英语", "数学"])



df4 = pd.DataFrame([
    ["张三", 90, 88, 85],
    ["李四", 85, 90, 88],
    ["王五", 88, 85, 90],
],columns=["姓名","语文","英语","数学"],index=[1,2,3])


#dataframe中 常见的属性

# df4.index  #index 获取索引

# df4.columns #columns 获取列名

# df4.values  #values 拿到具体的值

# df4.size   #size 元素的个数

# df4.dtypes   #获取每一列的类型

#df2.shape    #获取数据的维度(行,列)



s1 = pd.Series([10,20,30,40,50])

s2 = pd.Series((10,20,30,40,50),index=['a','b','c','d','e'])

s3 = pd.Series({'a':10,'b':20,'c':30,'d':40,3:50})

s4 = df4['语文']


#serise中常见的属性
s3.index #索引
s3.values #值
s3.size #元素的个数
s3.dtype #数据类型
s3.shape #维度(行, )
# Out:
# (5,)
