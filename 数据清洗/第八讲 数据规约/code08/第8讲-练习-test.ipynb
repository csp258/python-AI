# %% [markdown]
# # 第一题

# %% [markdown]
# 某公司记录了三种产品（产品X、产品Y、产品Z）在四个季度（Q1、Q2、Q3、Q4）的销售数据。原始数据以特殊格式存储，需要进行分析处理。

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 原始销售数据
columns = pd.MultiIndex.from_tuples([
    ('产品X', 'Q1'), ('产品X', 'Q2'), ('产品X', 'Q3'), ('产品X', 'Q4'),
    ('产品Y', 'Q1'), ('产品Y', 'Q2'), ('产品Y', 'Q3'), ('产品Y', 'Q4'),
    ('产品Z', 'Q1'), ('产品Z', 'Q2'), ('产品Z', 'Q3'), ('产品Z', 'Q4')
])

df_sales = pd.DataFrame([
    [125, 135, 145, 155, 115, 125, 135, 145, 180, 190, 200, 210]
], columns=columns, index=['销售额'])
df_sales

# %% [markdown]
# 要求：使用stack将原始数据转换为适合可视化的格式，最终数据包含三列：季度、产品、销售额，转换后的数据应该能够直接用于分组绘图。

# %%
# # 绘图
# # 设置中文字体（必须在绘图之前）
# plt.rcParams['font.sans-serif'] = ['SimHei']  # 使用黑体
# plt.rcParams['axes.unicode_minus'] = False    # 解决负号显示问题

# plt.figure(figsize=(10, 6))
# sns.barplot(data=df_plot, x='季度', y='销售额', hue='产品')
# plt.title('各产品季度销售额对比')
# plt.show()

# %% [markdown]
# ## 加分

# %% [markdown]
# # 第二题

# %% [markdown]
# 生成一个时间序列，起始日期：2000年1月1日，频率为1分钟（T/min表示分钟），日期（时间）个数为9个。生成后，降低采样频率为三分钟，并对时间求和。

# %%
index = pd.date_range('1/1/2000', periods=9, freq='min')
series = pd.Series(range(9), index=index)
series
